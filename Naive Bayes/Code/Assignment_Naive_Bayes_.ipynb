# %%
import numpy as np
import pandas as pd

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score

# %%
train = pd.read_csv("/content/SalaryData_Train.csv.crdownload")

# %%
test = pd.read_csv("/content/SalaryData_Test.csv")

# %%
train
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 12736   27            Private        HS-grad            9
# 12737   48            Private   Some-college           10
# 12738   31       Self-emp-inc        HS-grad            9
# 12739   31            Private        1st-4th            2
# 12740   18            Private           12th            8
#
#              maritalstatus          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial          Husband   White
# 2                 Divorced   Handlers-cleaners    Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners          Husband   Black
# 4       Married-civ-spouse      Prof-specialty             Wife   Black
# ...                    ...                 ...              ...     ...
# 12736        Never-married        Adm-clerical    Not-in-family   White
# 12737        Never-married   Handlers-cleaners    Not-in-family   White
# 12738        Never-married        Craft-repair    Not-in-family   White
# 12739        Never-married       Other-service   Other-relative   White
# 12740        Never-married               Sales        Own-child   White
#
#            sex  capitalgain  capitalloss  hoursperweek          native  Salary
# 0         Male         2174            0            40   United-States   <=50K
# 1         Male            0            0            13   United-States   <=50K
# 2         Male            0            0            40   United-States   <=50K
# 3         Male            0            0            40   United-States   <=50K
# 4       Female            0            0            40            Cuba   <=50K
# ...        ...          ...          ...           ...             ...     ...
# 12736     Male            0            0            50   United-States   <=50K
# 12737     Male            0            0            40   United-States   <=50K
# 12738     Male            0            0            44   United-States   <=50K
# 12739   Female            0            0            25     El-Salvador   <=50K
# 12740   Female            0            0            25                     NaN
#
# [12741 rows x 14 columns]

# %%
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12741 entries, 0 to 12740
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            12741 non-null  int64
#  1   workclass      12741 non-null  object
#  2   education      12741 non-null  object
#  3   educationno    12741 non-null  int64
#  4   maritalstatus  12741 non-null  object
#  5   occupation     12741 non-null  object
#  6   relationship   12741 non-null  object
#  7   race           12741 non-null  object
#  8   sex            12741 non-null  object
#  9   capitalgain    12741 non-null  int64
#  10  capitalloss    12741 non-null  int64
#  11  hoursperweek   12741 non-null  int64
#  12  native         12741 non-null  object
#  13  Salary         12740 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.4+ MB

# %%
train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  12741.000000  12741.000000  12741.000000  12741.000000  12741.000000
# mean      38.359391     10.124088   1076.078251     89.353897     41.028491
# std       13.088580      2.531913   7365.806668    404.272794     11.876268
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
test['maritalstatus'].value_counts()
# Out:
#  Married-civ-spouse       6990
#  Never-married            4872
#  Divorced                 2083
#  Separated                 472
#  Widowed                   450
#  Married-spouse-absent     182
#  Married-AF-spouse          11
# Name: maritalstatus, dtype: int64

# %%
train[train.duplicated()].shape
# Out:
# (752, 14)

# %%
train[train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 12693   39   Private        HS-grad            9   Married-civ-spouse
# 12700   21   Private   Some-college           10        Never-married
# 12702   51   Private        HS-grad            9   Married-civ-spouse
# 12718   35   Private        HS-grad            9   Married-civ-spouse
# 12725   32   Private        HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 326       Exec-managerial         Husband   White     Male            0
# 364          Craft-repair   Not-in-family   White     Male            0
# 518     Handlers-cleaners       Unmarried   Black   Female            0
# 525          Craft-repair       Own-child   White     Male            0
# 619       Exec-managerial         Husband   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 12693        Adm-clerical         Husband   White     Male            0
# 12700       Other-service       Own-child   White     Male            0
# 12702   Machine-op-inspct         Husband   White     Male            0
# 12718        Craft-repair         Husband   White     Male            0
# 12725        Craft-repair         Husband   White     Male            0
#
#        capitalloss  hoursperweek          native  Salary
# 326              0            40   United-States    >50K
# 364              0            50   United-States   <=50K
# 518              0            40   United-States   <=50K
# 525              0            40   United-States   <=50K
# 619              0            40   United-States    >50K
# ...            ...           ...             ...     ...
# 12693            0            40   United-States    >50K
# 12700            0            15   United-States   <=50K
# 12702            0            40   United-States   <=50K
# 12718            0            40   United-States   <=50K
# 12725            0            40   United-States   <=50K
#
# [752 rows x 14 columns]

# %%
Train=train.drop_duplicates()

# %%
Train.isnull().sum().sum()
# Out:
# 1

# %%
Train = Train.dropna()

# %%
Train.isnull().sum().sum()
# Out:
# 0

# %%
Train
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 12735   23            Private   Some-college           10
# 12736   27            Private        HS-grad            9
# 12737   48            Private   Some-college           10
# 12738   31       Self-emp-inc        HS-grad            9
# 12739   31            Private        1st-4th            2
#
#              maritalstatus          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial          Husband   White
# 2                 Divorced   Handlers-cleaners    Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners          Husband   Black
# 4       Married-civ-spouse      Prof-specialty             Wife   Black
# ...                    ...                 ...              ...     ...
# 12735        Never-married               Sales        Own-child   White
# 12736        Never-married        Adm-clerical    Not-in-family   White
# 12737        Never-married   Handlers-cleaners    Not-in-family   White
# 12738        Never-married        Craft-repair    Not-in-family   White
# 12739        Never-married       Other-service   Other-relative   White
#
#            sex  capitalgain  capitalloss  hoursperweek          native  Salary
# 0         Male         2174            0            40   United-States   <=50K
# 1         Male            0            0            13   United-States   <=50K
# 2         Male            0            0            40   United-States   <=50K
# 3         Male            0            0            40   United-States   <=50K
# 4       Female            0            0            40            Cuba   <=50K
# ...        ...          ...          ...           ...             ...     ...
# 12735   Female            0            0            40   United-States   <=50K
# 12736     Male            0            0            50   United-States   <=50K
# 12737     Male            0            0            40   United-States   <=50K
# 12738     Male            0            0            44   United-States   <=50K
# 12739   Female            0            0            25     El-Salvador   <=50K
#
# [11988 rows x 14 columns]

# %%
test[test.duplicated()].shape
# Out:
# (930, 14)

# %%
test[test.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# 551         Other-service   Not-in-family   White   Female            0
# 601                 Sales         Husband   White     Male            0
# 681          Craft-repair         Husband   White     Male            0
# 799        Prof-specialty   Not-in-family   White     Male            0
# 1044       Prof-specialty         Husband   White     Male        99999
# ...                   ...             ...     ...      ...          ...
# 15043        Craft-repair         Husband   White     Male            0
# 15044        Craft-repair       Own-child   White     Male            0
# 15049   Handlers-cleaners         Husband   White     Male            0
# 15052        Craft-repair         Husband   White     Male            0
# 15053       Other-service       Own-child   White   Female            0
#
#        capitalloss  hoursperweek          native  Salary
# 551              0            40   United-States   <=50K
# 601              0            40   United-States   <=50K
# 681              0            40   United-States   <=50K
# 799              0            35   United-States   <=50K
# 1044             0            60   United-States    >50K
# ...            ...           ...             ...     ...
# 15043            0            40   United-States   <=50K
# 15044            0            40   United-States   <=50K
# 15049            0            40   United-States   <=50K
# 15052            0            40   United-States   <=50K
# 15053            0            40   United-States   <=50K
#
# [930 rows x 14 columns]

# %%
Test=test.drop_duplicates()

# %%
Test.isnull().sum().sum()
# Out:
# 0

# %%
Test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [14130 rows x 14 columns]

# %%
Test.isnull().sum().sum()
# Out:
# 0

# %%
Train['Salary'].value_counts()
# Out:
#  <=50K    8991
#  >50K     2997
# Name: Salary, dtype: int64

# %%
Test['Salary'].value_counts()
# Out:
#  <=50K    10620
#  >50K      3510
# Name: Salary, dtype: int64

# %%
pd.crosstab(Train['occupation'],Train['Salary'])
# Out:
# Salary               <=50K   >50K
# occupation
#  Adm-clerical         1328    201
#  Armed-Forces            2      0
#  Craft-repair         1115    350
#  Exec-managerial       818    752
#  Farming-fishing       357     44
#  Handlers-cleaners     466     36
#  Machine-op-inspct     660    107
#  Other-service        1251     58
#  Priv-house-serv        63      0
#  Prof-specialty        920    734
#  Protective-serv       185     84
#  Sales                1094    385
#  Tech-support          234    115
#  Transport-moving      498    131

# %%
pd.crosstab(Train['workclass'],Train['Salary'])
# Out:
# Salary              <=50K   >50K
# workclass
#  Federal-gov          236    148
#  Local-gov            610    248
#  Private             6776   1914
#  Self-emp-inc         206    238
#  Self-emp-not-inc     755    297
#  State-gov            406    152
#  Without-pay            2      0

# %%
pd.crosstab(Train['workclass'],Train['occupation'])
# Out:
# occupation          Adm-clerical   Armed-Forces   Craft-repair  \
# workclass
#  Federal-gov                 127              2             28
#  Local-gov                   127              0             59
#  Private                    1115              0           1093
#  Self-emp-inc                 14              0             37
#  Self-emp-not-inc             30              0            225
#  State-gov                   116              0             23
#  Without-pay                   0              0              0
#
# occupation          Exec-managerial   Farming-fishing   Handlers-cleaners  \
# workclass
#  Federal-gov                     66                 2                   8
#  Local-gov                       82                13                  14
#  Private                       1031               182                 472
#  Self-emp-inc                   165                17                   1
#  Self-emp-not-inc               152               179                   5
#  State-gov                       74                 6                   2
#  Without-pay                      0                 2                   0
#
# occupation          Machine-op-inspct   Other-service   Priv-house-serv  \
# workclass
#  Federal-gov                        6              18                 0
#  Local-gov                          4              76                 0
#  Private                          722            1086                63
#  Self-emp-inc                       8              10                 0
#  Self-emp-not-inc                  20              63                 0
#  State-gov                          7              56                 0
#  Without-pay                        0               0                 0
#
# occupation          Prof-specialty   Protective-serv   Sales   Tech-support  \
# workclass
#  Federal-gov                    66                14       8             29
#  Local-gov                     305               121       4             12
#  Private                       880                80    1183            267
#  Self-emp-inc                   59                 2     117              1
#  Self-emp-not-inc              161                 3     164             11
#  State-gov                     183                49       3             29
#  Without-pay                     0                 0       0              0
#
# occupation          Transport-moving
# workclass
#  Federal-gov                      10
#  Local-gov                        41
#  Private                         516
#  Self-emp-inc                     13
#  Self-emp-not-inc                 39
#  State-gov                        10
#  Without-pay                       0

# %%
sns.countplot(x='Salary',data= Train)
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()
Train['Salary'].value_counts()
# Out:
#  <=50K    8991
#  >50K     2997
# Name: Salary, dtype: int64

# %%
sns.countplot(x='Salary',data= Test)
plt.xlabel('Salary')
plt.ylabel('count')
plt.show()
Test['Salary'].value_counts()
# Out:
#  <=50K    10620
#  >50K      3510
# Name: Salary, dtype: int64

# %%
sns.scatterplot(x='occupation', y='workclass', hue='Salary', data=Train)
# Out:
# <Axes: xlabel='occupation', ylabel='workclass'>

# %%
pd.crosstab(Train['Salary'],Train['education']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %%
pd.crosstab(Train['Salary'],Train['occupation']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='occupation'>

# %%
pd.crosstab(Train['Salary'],Train['workclass']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='workclass'>

# %%
pd.crosstab(Train['Salary'],Train['sex']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
pd.crosstab(Train['Salary'],Train['relationship']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='relationship'>

# %%
string_columns = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
number = LabelEncoder()
for i in string_columns:
        Train[i]= number.fit_transform(Train[i])
        Test[i]=number.fit_transform(Test[i])
# Out:
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])
# <ipython-input-139-b2b754760780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test[i]=number.fit_transform(Test[i])

# %%
Train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 12735   23          2         15           10              4          11
# 12736   27          2         11            9              4           0
# 12737   48          2         15           10              4           5
# 12738   31          3         11            9              4           2
# 12739   31          2          3            2              4           7
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 1     4    1         2174            0            40
# 1                 0     4    1            0            0            13
# 2                 1     4    1            0            0            40
# 3                 0     2    1            0            0            40
# 4                 5     2    0            0            0            40
# ...             ...   ...  ...          ...          ...           ...
# 12735             3     4    0            0            0            40
# 12736             1     4    1            0            0            50
# 12737             1     4    1            0            0            40
# 12738             1     4    1            0            0            44
# 12739             2     4    0            0            0            25
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37   <=50K
# 3          37   <=50K
# 4           4   <=50K
# ...       ...     ...
# 12735      37   <=50K
# 12736      37   <=50K
# 12737      37   <=50K
# 12738      37   <=50K
# 12739       7   <=50K
#
# [11988 rows x 14 columns]

# %%
Test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37    >50K
# 3          37    >50K
# 4          37   <=50K
# ...       ...     ...
# 15055      37   <=50K
# 15056      37   <=50K
# 15057      37   <=50K
# 15058      37   <=50K
# 15059      37    >50K
#
# [14130 rows x 14 columns]

# %%
colnames=Train.columns
colnames
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
len(colnames)
# Out:
# 14

# %%
Train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 12735   23          2         15           10              4          11
# 12736   27          2         11            9              4           0
# 12737   48          2         15           10              4           5
# 12738   31          3         11            9              4           2
# 12739   31          2          3            2              4           7
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 1     4    1         2174            0            40
# 1                 0     4    1            0            0            13
# 2                 1     4    1            0            0            40
# 3                 0     2    1            0            0            40
# 4                 5     2    0            0            0            40
# ...             ...   ...  ...          ...          ...           ...
# 12735             3     4    0            0            0            40
# 12736             1     4    1            0            0            50
# 12737             1     4    1            0            0            40
# 12738             1     4    1            0            0            44
# 12739             2     4    0            0            0            25
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37   <=50K
# 3          37   <=50K
# 4           4   <=50K
# ...       ...     ...
# 12735      37   <=50K
# 12736      37   <=50K
# 12737      37   <=50K
# 12738      37   <=50K
# 12739       7   <=50K
#
# [11988 rows x 14 columns]

# %%
Test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 3     2    1            0            0            40
# 1                 0     4    1            0            0            50
# 2                 0     4    1            0            0            40
# 3                 0     2    1         7688            0            40
# 4                 1     4    1            0            0            30
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37   <=50K
# 1          37   <=50K
# 2          37    >50K
# 3          37    >50K
# 4          37   <=50K
# ...       ...     ...
# 15055      37   <=50K
# 15056      37   <=50K
# 15057      37   <=50K
# 15058      37   <=50K
# 15059      37    >50K
#
# [14130 rows x 14 columns]

# %%
Test['maritalstatus'].value_counts()
# Out:
# 2    6490
# 4    4501
# 0    2026
# 5     470
# 6     450
# 3     182
# 1      11
# Name: maritalstatus, dtype: int64

# %%
x_train = Train[colnames[0:13]].values
y_train = Train[colnames[13]].values
x_test = Test[colnames[0:13]].values
y_test = Test[colnames[13]].values

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_train
# Out:
# array([[39,  5,  9, ...,  0, 40, 37],
#        [50,  4,  9, ...,  0, 13, 37],
#        [38,  2, 11, ...,  0, 40, 37],
#        ...,
#        [48,  2, 15, ...,  0, 40, 37],
#        [31,  3, 11, ...,  0, 44, 37],
#        [31,  2,  3, ...,  0, 25,  7]])

# %%
x_test
# Out:
# array([[25,  2,  1, ...,  0, 40, 37],
#        [38,  2, 11, ...,  0, 50, 37],
#        [28,  1,  7, ...,  0, 40, 37],
#        ...,
#        [38,  2,  9, ...,  0, 50, 37],
#        [44,  2,  9, ...,  0, 40, 37],
#        [35,  3,  9, ...,  0, 60, 37]])

# %%
y_train
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       dtype=object)

# %%
y_test
# Out:
# array([' <=50K', ' <=50K', ' >50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
x_train = norm_func(x_train)
x_test =  norm_func(x_test)

# %% [markdown]
# #Applying Naive Bayes for Classification**

# %%
from sklearn.naive_bayes import MultinomialNB as MB

M_model=MB()
train_pred_multi=M_model.fit(x_train,y_train).predict(x_train)
test_pred_multi=M_model.fit(x_train,y_train).predict(x_test)

# %%
train_acc_multi=np.mean(train_pred_multi==y_train)
train_acc_multi
# Out:
# 0.75

# %%
test_acc_multi=np.mean(test_pred_multi==y_test)
test_acc_multi ## test acuracy 75.15
# Out:
# 0.7515923566878981

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, test_pred_multi)

# %%
confusion_matrix
# Out:
# array([[10620,     0],
#        [ 3510,     0]])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,test_pred_multi))
# Out:
# 0.7515923566878981

# %%
from sklearn.naive_bayes import GaussianNB as GB
G_model=GB()
train_pred_gau=G_model.fit(x_train,y_train).predict(x_train)
test_pred_gau=G_model.fit(x_train,y_train).predict(x_test)

# %%
train_acc_gau=np.mean(train_pred_gau==y_train)
train_acc_gau ## train accuracy 79.33
# Out:
# 0.7974641307974641

# %%
test_acc_gau=np.mean(test_pred_gau==y_test)
test_acc_gau ## test acuracy 79.57
# Out:
# 0.7967445152158528

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, test_pred_gau)

# %%
confusion_matrix
# Out:
# array([[10063,   557],
#        [ 2315,  1195]])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,test_pred_gau))
# Out:
# 0.7967445152158528
